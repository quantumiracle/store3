# %%
plt.figure(figsize=(20,3))
results=np.load('edge00.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
# norm factor for sim-to-real transfer
a=200
b=0.003
shift=4  # frame shift
predict = predict/a-b
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('edge_00.pdf', bbox_inches='tight')
# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0008793212849510307, 0.0006483664871465975)

# %%
plt.figure(figsize=(20,3))
results=np.load('edge02.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
# norm factor for sim-to-real transfer
a=200
b=0.002
shift=4  # frame shift
predict = predict/a-b
plt.plot(predict[shift:], '-o', color='b')
plt.plot(label[:-shift], '-o',color='r')
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('edge_02.pdf', bbox_inches='tight')
# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0012065745375875044, 0.000980733921453357)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
results=np.load('edge04.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
# norm factor for sim-to-real transfer
a=150
b=0.005
shift=4  # frame shift
predict = predict/a-b
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('edge_04.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0004519294645976693, 0.0002963690426332476)

# %%
# plot
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
results=np.load('edge04.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
# norm factor for sim-to-real transfer
a=150
b=0.005
shift=4  # frame shift
predict = predict/a-b
plt.plot(predict[shift:25], '-o', color='b', label='Prediction')
plt.plot(label[:25-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('edge_04_show.pdf', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
results=np.load('edge06.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
# norm factor for sim-to-real transfer
a=320
b=-0.001
shift=4  # frame shift
predict = predict/a-b
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend()
plt.grid()
plt.savefig('edge_06.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0008045677128822679, 0.0005337757786967934)

# %%
# randomization vs mae
plt.figure(figsize=(4,3))
randomization=[0.0,0.2,0.4,0.6]
mae=[0.000879, 0.001206, 0.0004519, 0.0008045 ]
std=[0.00064836, 0.0009807,0.0002963, 0.0005337]
# plt.plot(randomization, mae)
plt.errorbar(randomization, mae, std, fmt='-o', capsize=5)
plt.title('Angle Prediction', fontsize=13)
plt.xlabel('Randomization Range', fontsize=13)
plt.ylabel('Mean Absolute Error', fontsize=13)
plt.grid()
plt.savefig('edge_compare.pdf')
