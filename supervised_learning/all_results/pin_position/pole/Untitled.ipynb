# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
results=np.load('pole00.npy', allow_pickle=True)
predict=results[:, 0]
label=results[:, 1]
# norm factor for sim-to-real transfer
a0=160
b0=0.001
a1=160
b1=0.002
shift=4  # frame shift
predict = np.transpose([predict[:, 0]/a0-b0, predict[:, 1]/a1-b1])
# predict = predict/a0-b0
plt.subplot(2,1,1)
plt.plot(predict[shift:,0], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,0], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.subplot(2,1,2)
plt.plot(predict[shift:,1], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,1], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Y-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.savefig('pole_00.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0010222379861197677, 0.001717445193234125)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
results=np.load('pole02.npy', allow_pickle=True)
predict=results[:, 0]
label=results[:, 1]
# norm factor for sim-to-real transfer
a0=180
b0=0.001
a1=160
b1=0.002
shift=4  # frame shift
predict = np.transpose([predict[:, 0]/a0-b0, predict[:, 1]/a1-b1])
# predict = predict/a0-b0
plt.subplot(2,1,1)
plt.plot(predict[shift:,0], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,0], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.subplot(2,1,2)
plt.plot(predict[shift:,1], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,1], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Y-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.savefig('pole_02.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0007264720946736844, 0.0007688605717496957)

# %%
# plot 
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))
results=np.load('pole02.npy', allow_pickle=True)
predict=results[:, 0]
label=results[:, 1]
# norm factor for sim-to-real transfer
a0=180
b0=0.001
a1=160
b1=0.002
shift=4  # frame shift
predict = np.transpose([predict[:, 0]/a0-b0, predict[:, 1]/a1-b1])
predict=predict*1000 # change to mm unit
label=label*1000 
# predict = predict/a0-b0
plt.subplot(2,1,1)
plt.title('Task III', fontsize=13)
plt.plot(predict[shift:25,0], '-o', color='b', label='Prediction')
plt.plot(label[:25-shift,0], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-axis (mm)', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.subplot(2,1,2)
plt.plot(predict[shift:25,1], '-o', color='b', label='Prediction')
plt.plot(label[:25-shift,1], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Y-axis (mm)', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.savefig('pole_02_show.pdf', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
results=np.load('pole04.npy', allow_pickle=True)
predict=results[:, 0]
label=results[:, 1]
# norm factor for sim-to-real transfer
a0=160
b0=0.001
a1=170
b1=-0.001
shift=4  # frame shift
predict = np.transpose([predict[:, 0]/a0-b0, predict[:, 1]/a1-b1])
# predict = predict/a0-b0
plt.subplot(2,1,1)
plt.plot(predict[shift:,0], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,0], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.subplot(2,1,2)
plt.plot(predict[shift:,1], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,1], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Y-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.savefig('pole_04.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0011401761707362814, 0.0013367484655373188)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
results=np.load('pole06.npy', allow_pickle=True)
predict=results[:, 0]
label=results[:, 1]
# norm factor for sim-to-real transfer
a0=150
b0=0.001
a1=180
b1=0.000
shift=4  # frame shift
predict = np.transpose([predict[:, 0]/a0-b0, predict[:, 1]/a1-b1])
# predict = predict/a0-b0
plt.subplot(2,1,1)
plt.plot(predict[shift:,0], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,0], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('X-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.subplot(2,1,2)
plt.plot(predict[shift:,1], '-o', color='b', label='Prediction')
plt.plot(label[:-shift,1], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Y-position', fontsize=13)
plt.legend(loc=1)
plt.grid()

plt.savefig('pole_06.pdf', bbox_inches='tight')

# error
abs_error=np.abs(predict[shift:]- label[:-shift])
print(np.argwhere(abs_error>0.1))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.0012945373936938608, 0.0014544400470978076)

# %%
# randomization vs mae
plt.figure(figsize=(4,3))
randomization=[0.0,0.2,0.4,0.6]
mae=np.array([0.001022, 0.0007264, 0.001140, 0.0012945 ])*1000 # change to mm unit
std=np.array([0.001717, 0.0007688,0.001336, 0.001454])*1000
# plt.plot(randomization, mae)
plt.errorbar(randomization, mae, std, fmt='-o', capsize=5)
plt.title('III. Position Prediction (X, Y)', fontsize=13)
plt.xlabel('Randomization Range', fontsize=13)
plt.ylabel('Mean Absolute Error (mm)', fontsize=13)
plt.grid()
plt.savefig('pole_compare.pdf', bbox_inches='tight')
