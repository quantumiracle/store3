# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
results=np.load('circle00.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
predict = predict-0.2# callibrate overall error
shift=4
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Radian', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('circle_00.pdf', bbox_inches='tight')
# error
abs_error=np.abs(predict[shift:120]- label[:120-shift])
print(np.argwhere(abs_error>5))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.6863388750607536, 0.6061270123562684)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
results=np.load('circle02.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
predict = predict-0.2# callibrate overall error
shift=5
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Radian', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('circle_02.pdf', bbox_inches='tight')
# error
abs_error=np.abs(predict[shift:120]- label[:120-shift])
print(np.argwhere(abs_error>5))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.3248229774803163, 0.23065062771993888)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
results=np.load('circle04.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
predict = predict-0.21# callibrate overall error
plt.plot(predict[5:], '-o', color='b')  
plt.plot(label[:-5], '-o',color='r')
plt.grid()
# error
abs_error=np.abs(predict[5:]- label[:-5])
print(np.argwhere(abs_error>5))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.2539006629308371, 0.23456253231378738)

# %%
# plot
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
results=np.load('circle04.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
predict = predict-0.21# callibrate overall error
plt.plot(predict[5:30], '-o', color='b', label='Prediction')  
plt.plot(label[:30-5], '-o',color='r', label='Ground Truth')
plt.grid()
plt.title('Task I',fontsize=13)
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Angle', fontsize=13)
plt.legend(loc=2)
plt.savefig('circle_04_show.pdf', bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
results=np.load('circle06.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
predict = predict-0.2# callibrate overall error
shift=4
plt.plot(predict[shift:], '-o', color='b', label='Prediction')
plt.plot(label[:-shift], '-o',color='r', label='Ground Truth')
plt.xlabel('Sample', fontsize=13)
plt.ylabel('Radian', fontsize=13)
plt.legend(loc=1)
plt.grid()
plt.savefig('circle_06.pdf', bbox_inches='tight')
# error
abs_error=np.abs(predict[shift:120]- label[:120-shift])
print(np.argwhere(abs_error>5))  # make sure no alignment error
print('mean, std: ', np.mean(abs_error), np.std(abs_error))
# Out:
# []
# ('mean, std: ', 0.5785461365926735, 0.6247527447319817)

# %%
# randomization vs mae
plt.figure(figsize=(4,3))
randomization=[0.0,0.2,0.4,0.6]
mae=[0.6863, 0.3248, 0.2539, 0.578546 ]
std=[0.606127, 0.23065,0.23456, 0.62475]
# plt.plot(randomization, mae)
plt.errorbar(randomization, mae, std, fmt='-o', capsize=5)
plt.title('I. Angle Prediction', fontsize=13)
plt.xlabel('Randomization Range', fontsize=13)
plt.ylabel('Mean Absolute Error', fontsize=13)
plt.grid()
plt.savefig('circle_compare.pdf', bbox_inches='tight')

# %%
plt.figure(figsize=(20,5))
results=np.load('circle00.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
plt.plot(predict[5:], '-o', color='b')
plt.plot(label, '-o',color='r')

# %%
plt.figure(figsize=(20,5))
results=np.load('circle06.npy', allow_pickle=True)
[predict, label]=np.transpose(results)
plt.plot(predict[4:], '-o', color='b')
plt.plot(label, '-o',color='r')
